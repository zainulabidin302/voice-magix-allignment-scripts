# %%
import numpy as np
import pandas as pd
import sys
import os
from subprocess import check_output
import time
# sys.path.append('/homedtic/georgid/workspace/AlignmentMagix/src/align/')
# import doit

perfs_file = '/mnt/vmdata/camut/DAMP/perfs20.csv'

df = pd.read_csv(perfs_file, header=None)

lyrics_folder = '/mnt/vmdata/camut/DAMP/lyrics/'
wav_songs_folder = '/mnt/vmdata/camut/DAMP/DAMP_from_smule_website_wav/'
output_folder = '/mnt/vmdata/camut/DAMP/alignments_DNN/'


def check(item):
    s_name = os.path.join(wav_songs_folder, "{}.wav".format(item[1][1]))
    l_name = os.path.join(lyrics_folder, item[1][2])
    out = os.path.join(output_folder, "{}.txt".format(item[1][1]))
    
#     print(item[1][1], item[1][2])

    if os.path.isfile(out):
        return ('{} exist'.format(out).split('/')[-1])
    else:
        output = check_output(['python', '/homedtic/georgid/workspace/AlignmentMagix/src/align/doit.py', s_name, l_name, '0', out])    
        return ('{} == {}'.format(('{} exist'.format(out).split('/')[-1]), output))

def ite(rows, nrows=4):
    
    ls = []
    counter = 0
    for item in df.iterrows():
        ls.append(item)
        
        if counter == nrows:
            yield ls
            ls = []
            counter = 0
        else:
            counter = counter + 1
        
        
        
with open('time_{}_logger.txt'.format(time.time()), 'w') as f:

    for item in ite(df.iterrows(), nrows=8):
        start = time.time()
        pool = mp.Pool(processes=8)
        results = pool.map(check, item)

        f.write ('\n results: {} \n time: {} '.format(time.time() - start, ' \n '.join(results)))
# print(song_name)
# print(lyrics_name)


# !python /homedtic/georgid/workspace/AlignmentMagix/src/align/doit.py /mnt/vmdata/camut/DAMP/DAMP_from_smule_website_wav/131698369_27844120.wav lyrics_data/_all_american_girl 0 output.lab

# %%
from IPython.display import Audio 
from subprocess import check_output

output = check_output(['sed','-n', "1,20p", str(lyrics_name)])
output = check_output(['sed','-n', "1,20p", str(output.lab)])

print(str(output))
# print(20*'*', 'Alignments', 20*'*', )
# print(52*'*')
# !sed -n "1,20p" output.lab | cat -n
# print(20*'*', 'Lyrics', 20*'*', )
# print(48*'*')
# # check_output(['sed', ' -n "1,20p" lyrics_name'])
# Out:
# b'RIFF$\x07\x8c\x00WAVEfmt \x10\x00\x00\x00\x01\x00\x01\x00"V\x00\x00D\xac\x00\x00\x02\x00\x10\x00data\n\n\x00\xfc\xff\xf6\xff\x00\x00\r\x00\x13\x00\x18\x00\x10\x00\x03\x00\x0e\x00\x12\x00\t\x00\x0f\x00\x07\x00\x0e\x00\x1a\x00\x18\x00\x0f\x00\x0b\x00\x0b\x00\x03\x00\xf0\xff\xfd\xff\x18\x00\x0b\x00\xfd\xff\xfe\xff\x06\x00\xf4\xff\xe9\xff\xf1\xff\xf3\xff\xf1\xff\xe7\xff\xe9\xff\xe5\xff\xf5\xff\t\x00\xf3\xff\xf3\xff\x05\x00\xfe\xff\xff\xff\x05\x00\x07\x00\xf7\xff\xf3\xff\x03\x00\xfc\xff\xf6\xff\x03\x00\x0c\x00\x0b\x00\x08\x00\x0f\x00\x18\x00\t\x00\x06\x00\x0f\x00\x07\x00\xfc\xff\x00\x00\xf4\xff\xf4\xff\x04\x00\xf2\xff\xeb\xff\xf0\xff\xef\xff\xf7\xff\x05\x00\xfc\xff\xf9\xff\xf0\xff\xf3\xff\xf7\xff\xf9\xff\x0f\x00\x17\x00\x18\x00\t\x00\x0b\x00\r\x00\x05\x00\xfb\xff\x0e\x00\x18\x00\x10\x00\n\x00\x0b\x00\x18\x00\x17\x00\x06\x00\x18\x00\x16\x00